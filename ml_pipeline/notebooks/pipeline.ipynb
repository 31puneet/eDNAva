# %%
import os
if os.getcwd().endswith('notebooks'):
    os.chdir('../../')
print('Working directory explicitly set to:', os.getcwd())

# %%
# !python ml_pipeline/src/dataset.py

# %%
# !python ml_pipeline/src/process.py

# %%
# !python ml_pipeline/src/train.py

# %%
# !python ml_pipeline/src/predictor.py
